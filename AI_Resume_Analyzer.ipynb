# %% [markdown]
# <a href="https://colab.research.google.com/github/s-abouali/-C-File-Handling-Program/blob/main.c/AI_Resume_Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 1.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded)
file_name = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-6849212a-73b2-45f4-8d75-fa38d035ec63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6849212a-73b2-45f4-8d75-fa38d035ec63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import PyPDF2
def read_resume(file_path):

  text = ""

  with open(file_path, "rb") as file:

    reader = PyPDF2.PdfReader(file)

    for page in reader.pages:

      text += page.extract_text()

  return text

print(read_resume(file_name))
# Out:
# ALEX MORGAN
# Boston, MA  (617) 555-0148  alex.morgan@email.com  linkedin.com/in/alexmorgan  github.com/alexmorgan
# EDUCATION
# Massachusetts Institute of Technology (MIT), Cambridge, MA
# B.S. in Computer Science and Artificial Intelligence    Expected May 2028
# Relevant Coursework: Machine Learning, Data Structures & Algorithms, Linear Algebra, Probability & Statistics
# TECHNICAL SKILLS
# Languages: Python, Java, C++, SQL, JavaScript
# AI/ML: scikit-learn, PyTorch, TensorFlow, Pandas, NumPy, OpenCV
# Tools: Git, GitHub, Docker, Jupyter, Linux, VS Code
# PROJECTS
# AI Resume Analyzer | Python, NLP, scikit-learn, Streamlit
#  Built an NLP application that compares resumes with job descriptions and produces a skills-match score.
#  Implemented text preprocessing, TF-IDF feature extraction, cosine similarity, and automated skill-gap recommendations.
#  Developed a Streamlit interface for resume upload and structured analysis.
# ...

# %%
pip install google-genai

# %%
from google.colab import userdata

# %%
from google import genai

client = genai.Client(api_key=userdata.get("GOOGLE_API_KEY"))

# %%
def analyze_resume(text):
   response = client.models.generate_content(
       model="gemini-3.5-flash-lite",
       contents= f"""
You are an ATS resume analyzer.

Analyze the resume below and return ATS score and feedback.

Resume:
{text}

Return in JSON format with:
- ats_score (0-100)
- summary
- strengths
- weaknesses

Rules:
- Output ONLY JSON
- No extra text
"""
   )
   return response.text

# %%
resume_text = read_resume(file_name)
result = analyze_resume(resume_text)
print(result)
# Out:
# {
#   "ats_score": 92,
#   "summary": "This is a very strong, highly targeted resume for an entry-level software engineering or machine learning role. It features a prestigious educational background (MIT), relevant technical skills categorized clearly, impactful project descriptions with quantifiable context, and solid internship experience. The layout is clean and ATS-friendly, though formatting minor tweaks could push the score even higher.",
#   "strengths": [
#     "Strong educational pedigree (MIT) with a relevant degree and coursework.",
#     "Well-categorized technical skills section containing high-demand languages, frameworks, and tools.",
#     "Action-oriented project and experience bullet points featuring specific metrics (e.g., '50,000+ records', '30% reduction').",
#     "Clean chronological structure with standard headings that parse well in ATS systems."
#   ],
#   "weaknesses": [
# ...
